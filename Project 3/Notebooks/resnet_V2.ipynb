# %%
import os
import torch
import random
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchsummary import summary

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

resnet_type = "resnet18"
image_size = 224
batch_size = 8
num_epochs = 100
learning_rate = 0.01
num_classes = 4

train_dir = "./../../Project 3/data/Data_cleaning_step1_2/Train"
test_dir = "./../../Project 3/data/Data_cleaning_step1_2/Test"

# Define the transformations for train data before entering the neural network
transform_train = transforms.Compose([
    transforms.Resize((image_size, image_size)),                                    # Resize images to 224x224 pixels
    transforms.RandomCrop(size=image_size),                                         # Randomly crop and resize images to 224x224 pixels
    transforms.RandomHorizontalFlip(),                                              # Randomly flip the images horizontally
    transforms.RandomRotation(30),                                                  # Randomly rotate the images by 30 degrees
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Randomly adjust brightness, contrast, saturation, and hue
    transforms.ToTensor(),                                                          # Convert images to tensors
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])                 # Normalize the images
])

# Define the transformations for test data before entering the neural network
transform_test = transforms.Compose([
    transforms.Resize((image_size, image_size)),                     # Resize images to 224x224 pixels
    transforms.ToTensor(),                                           # Convert images to tensors
    transforms.Normalize( mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize the images
])

# Load the training and test datasets
train_dataset = ImageFolder(train_dir, transform=transform_train)
# val_dataset = ImageFolder(test_dir, transform=transform_test)
# test_dataset = ImageFolder(test_dir, transform=transform_test)

# Create DataLoaders for training, validation, and test datasets
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

# Split the dataset into training, validation, and test sets
dataset_size = len(train_dataset)
train_size = int(train_ratio * dataset_size)
val_size = int(val_ratio * dataset_size)
test_size = dataset_size - train_size - val_size

train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
    train_dataset, [train_size, val_size, test_size])


# Create DataLoaders for managing the data batches
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Resnet model
resnet = models.resnet18(pretrained=True)
num_features = resnet.fc.in_features
resnet.fc = nn.Linear(num_features, num_classes)
resnet = resnet.to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(resnet.parameters(), lr=learning_rate)

# Train the model
total_test_acc = []
total_val_acc = []
total_loss = []

for epoch in range(num_epochs):
    resnet.train()
    train_loss = 0.0
    train_correct = 0
    losses = []

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        outputs = resnet(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())

        train_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs.data, 1)
        train_correct += (predicted == labels).sum().item()
        
    train_loss = train_loss / len(train_dataset)
    train_acc = (train_correct / len(train_dataset))*100
    total_loss.append(sum(losses)/len(train_dataset))
    
    # Validate the model
    resnet.eval()  # Set the model to evaluation mode
    val_correct = 0
    val_samples = 0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
        
            outputs = resnet(images)
            _, predicted = torch.max(outputs.data, 1)
            val_samples += labels.size(0)
            val_correct += (predicted == labels).sum().item()
            
    val_acc = 100 * val_correct / val_samples
    total_val_acc.append(val_acc)
    
    # Evaluate the model
    resnet.eval()  # Set the model to evaluation mode
    total_correct = 0
    total_samples = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
        
            outputs = resnet(images)
            _, predicted = torch.max(outputs.data, 1)
            total_samples += labels.size(0)
            total_correct += (predicted == labels).sum().item()
            
            
    test_acc = 100 * total_correct / total_samples
    total_test_acc.append(test_acc)
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Test Accuracy: {test_acc:.2f}%, val Accuracy: {val_acc:.2f}%")           

# Save model
torch.save(resnet.state_dict(), "model_apple_resnet.pth")

data = {
    "Model type": resnet_type,
    "Dataset use": os.path.basename(train_dir),
    "Image Resize": str(image_size)+"*"+str(image_size),
    "Epochs": num_epochs,
    "Learning rate": learning_rate,
    "Batch size": batch_size,
    "Train Accuracy": f"{train_acc:.2f}",
    "Validation accuracy": f"{val_acc:.2f}",
    "Test Accuracy": f"{test_acc:.2f}",
    
    
}

# Check if the CSV file already exists
if os.path.isfile("model_data.csv"):
    existing_data = pd.read_csv("model_data.csv")
    new_data = pd.concat([existing_data, pd.DataFrame(data, index=[0])], ignore_index=True)

else:
    new_data = pd.DataFrame(data, index=[0])

# Save the updated DataFrame to CSV
new_data.to_csv("model_data.csv", index=False)


# Plot training and validation accuracy
fig, ax = plt.subplots()
ax.set(xlabel='Epoch', ylabel='Accuracy', title="Training and Validation Accuracy")

epochs = range(1, num_epochs + 1)
plt.plot(epochs, total_test_acc, label='Training Accuracy')
plt.plot(epochs, total_val_acc, label='Validation Accuracy')
plt.legend()
plt.show()
# Out:
# cpu
# C:\Users\HansW\mitwworkspace\MakeAIWork2\env\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\HansW\mitwworkspace\MakeAIWork2\env\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch [1/100], Train Loss: 2.7020, Train Accuracy: 31.16%, Test Accuracy: 34.29%, val Accuracy: 34.29%
# Epoch [2/100], Train Loss: 1.8668, Train Accuracy: 33.33%, Test Accuracy: 20.00%, val Accuracy: 17.14%
# Epoch [3/100], Train Loss: 1.5430, Train Accuracy: 37.32%, Test Accuracy: 48.57%, val Accuracy: 48.57%
# Epoch [4/100], Train Loss: 1.3775, Train Accuracy: 44.57%, Test Accuracy: 54.29%, val Accuracy: 65.71%
# Epoch [5/100], Train Loss: 1.3500, Train Accuracy: 47.46%, Test Accuracy: 42.86%, val Accuracy: 40.00%
# Epoch [6/100], Train Loss: 1.2906, Train Accuracy: 45.29%, Test Accuracy: 51.43%, val Accuracy: 51.43%
# Epoch [7/100], Train Loss: 1.3088, Train Accuracy: 42.03%, Test Accuracy: 22.86%, val Accuracy: 22.86%
# Epoch [8/100], Train Loss: 1.2240, Train Accuracy: 45.29%, Test Accuracy: 28.57%, val Accuracy: 25.71%
# Epoch [9/100], Train Loss: 1.2176, Train Accuracy: 45.65%, Test Accuracy: 40.00%, val Accuracy: 34.29%
# Epoch [10/100], Train Loss: 1.3783, Train Accuracy: 43.84%, Test Accuracy: 40.00%, val Accuracy: 31.43%
# Epoch [11/100], Train Loss: 1.2040, Train Accuracy: 47.83%, Test Accuracy: 45.71%, val Accuracy: 48.57%
# Epoch [12/100], Train Loss: 1.1855, Train Accuracy: 48.19%, Test Accuracy: 57.14%, val Accuracy: 57.14%
# Epoch [13/100], Train Loss: 1.1493, Train Accuracy: 52.17%, Test Accuracy: 42.86%, val Accuracy: 62.86%
# Epoch [14/100], Train Loss: 1.1748, Train Accuracy: 48.19%, Test Accuracy: 40.00%, val Accuracy: 45.71%
# Epoch [15/100], Train Loss: 1.1573, Train Accuracy: 48.19%, Test Accuracy: 51.43%, val Accuracy: 57.14%
# Epoch [16/100], Train Loss: 1.1052, Train Accuracy: 50.36%, Test Accuracy: 62.86%, val Accuracy: 68.57%
# Epoch [17/100], Train Loss: 1.1249, Train Accuracy: 53.26%, Test Accuracy: 65.71%, val Accuracy: 60.00%
# Epoch [18/100], Train Loss: 1.0808, Train Accuracy: 52.54%, Test Accuracy: 60.00%, val Accuracy: 57.14%
# Epoch [19/100], Train Loss: 1.0782, Train Accuracy: 55.07%, Test Accuracy: 65.71%, val Accuracy: 62.86%
# Epoch [20/100], Train Loss: 1.0563, Train Accuracy: 54.35%, Test Accuracy: 65.71%, val Accuracy: 60.00%
# Epoch [21/100], Train Loss: 1.0750, Train Accuracy: 55.07%, Test Accuracy: 68.57%, val Accuracy: 71.43%
# Epoch [22/100], Train Loss: 1.1007, Train Accuracy: 56.16%, Test Accuracy: 77.14%, val Accuracy: 71.43%
# Epoch [23/100], Train Loss: 1.0985, Train Accuracy: 50.72%, Test Accuracy: 60.00%, val Accuracy: 51.43%
# Epoch [24/100], Train Loss: 1.0986, Train Accuracy: 54.71%, Test Accuracy: 57.14%, val Accuracy: 57.14%
# Epoch [25/100], Train Loss: 1.0919, Train Accuracy: 52.90%, Test Accuracy: 31.43%, val Accuracy: 40.00%
# Epoch [26/100], Train Loss: 1.0712, Train Accuracy: 52.54%, Test Accuracy: 62.86%, val Accuracy: 68.57%
# Epoch [27/100], Train Loss: 1.0443, Train Accuracy: 57.61%, Test Accuracy: 42.86%, val Accuracy: 42.86%
# Epoch [28/100], Train Loss: 1.0571, Train Accuracy: 50.72%, Test Accuracy: 60.00%, val Accuracy: 68.57%
# Epoch [29/100], Train Loss: 1.0927, Train Accuracy: 52.90%, Test Accuracy: 54.29%, val Accuracy: 57.14%
# Epoch [30/100], Train Loss: 1.1283, Train Accuracy: 51.81%, Test Accuracy: 57.14%, val Accuracy: 57.14%
# Epoch [31/100], Train Loss: 1.0804, Train Accuracy: 52.90%, Test Accuracy: 45.71%, val Accuracy: 51.43%
# Epoch [32/100], Train Loss: 1.0571, Train Accuracy: 51.09%, Test Accuracy: 65.71%, val Accuracy: 71.43%
# Epoch [33/100], Train Loss: 1.0519, Train Accuracy: 55.80%, Test Accuracy: 28.57%, val Accuracy: 34.29%
# Epoch [34/100], Train Loss: 1.0460, Train Accuracy: 55.43%, Test Accuracy: 60.00%, val Accuracy: 62.86%
# Epoch [35/100], Train Loss: 0.9968, Train Accuracy: 59.42%, Test Accuracy: 54.29%, val Accuracy: 40.00%
# Epoch [36/100], Train Loss: 1.0653, Train Accuracy: 52.90%, Test Accuracy: 62.86%, val Accuracy: 68.57%
# Epoch [37/100], Train Loss: 1.0116, Train Accuracy: 55.80%, Test Accuracy: 60.00%, val Accuracy: 54.29%
# Epoch [38/100], Train Loss: 0.9649, Train Accuracy: 56.88%, Test Accuracy: 48.57%, val Accuracy: 40.00%
# Epoch [39/100], Train Loss: 0.9611, Train Accuracy: 57.97%, Test Accuracy: 57.14%, val Accuracy: 51.43%
# Epoch [40/100], Train Loss: 0.9792, Train Accuracy: 56.88%, Test Accuracy: 48.57%, val Accuracy: 37.14%
# Epoch [41/100], Train Loss: 0.9397, Train Accuracy: 57.25%, Test Accuracy: 60.00%, val Accuracy: 62.86%
# Epoch [42/100], Train Loss: 1.0063, Train Accuracy: 57.97%, Test Accuracy: 48.57%, val Accuracy: 62.86%
# Epoch [43/100], Train Loss: 0.8647, Train Accuracy: 65.22%, Test Accuracy: 51.43%, val Accuracy: 62.86%
# Epoch [44/100], Train Loss: 0.9528, Train Accuracy: 62.32%, Test Accuracy: 54.29%, val Accuracy: 51.43%
# Epoch [45/100], Train Loss: 1.0526, Train Accuracy: 56.16%, Test Accuracy: 62.86%, val Accuracy: 57.14%
# Epoch [46/100], Train Loss: 1.0259, Train Accuracy: 55.07%, Test Accuracy: 60.00%, val Accuracy: 60.00%
# Epoch [47/100], Train Loss: 0.9082, Train Accuracy: 59.78%, Test Accuracy: 62.86%, val Accuracy: 57.14%
# Epoch [48/100], Train Loss: 0.8879, Train Accuracy: 63.41%, Test Accuracy: 65.71%, val Accuracy: 57.14%
# Epoch [49/100], Train Loss: 0.8653, Train Accuracy: 65.94%, Test Accuracy: 57.14%, val Accuracy: 51.43%
# Epoch [50/100], Train Loss: 0.8905, Train Accuracy: 61.96%, Test Accuracy: 48.57%, val Accuracy: 57.14%
# Epoch [51/100], Train Loss: 0.9426, Train Accuracy: 59.42%, Test Accuracy: 68.57%, val Accuracy: 71.43%
# Epoch [52/100], Train Loss: 0.8431, Train Accuracy: 59.78%, Test Accuracy: 57.14%, val Accuracy: 54.29%
# Epoch [53/100], Train Loss: 0.8923, Train Accuracy: 64.49%, Test Accuracy: 65.71%, val Accuracy: 57.14%
# Epoch [54/100], Train Loss: 0.8253, Train Accuracy: 65.22%, Test Accuracy: 60.00%, val Accuracy: 62.86%
# Epoch [55/100], Train Loss: 0.8427, Train Accuracy: 61.96%, Test Accuracy: 42.86%, val Accuracy: 34.29%
# Epoch [56/100], Train Loss: 0.8794, Train Accuracy: 65.94%, Test Accuracy: 57.14%, val Accuracy: 62.86%
# Epoch [57/100], Train Loss: 0.8592, Train Accuracy: 65.22%, Test Accuracy: 51.43%, val Accuracy: 48.57%
# Epoch [58/100], Train Loss: 0.9499, Train Accuracy: 61.23%, Test Accuracy: 48.57%, val Accuracy: 57.14%
# Epoch [59/100], Train Loss: 0.8195, Train Accuracy: 65.22%, Test Accuracy: 65.71%, val Accuracy: 54.29%
# Epoch [60/100], Train Loss: 0.8437, Train Accuracy: 60.87%, Test Accuracy: 54.29%, val Accuracy: 57.14%
# Epoch [61/100], Train Loss: 0.8154, Train Accuracy: 66.30%, Test Accuracy: 48.57%, val Accuracy: 57.14%
# Epoch [62/100], Train Loss: 0.8582, Train Accuracy: 63.41%, Test Accuracy: 74.29%, val Accuracy: 65.71%
# Epoch [63/100], Train Loss: 0.8292, Train Accuracy: 67.39%, Test Accuracy: 48.57%, val Accuracy: 45.71%
# Epoch [64/100], Train Loss: 0.8589, Train Accuracy: 65.22%, Test Accuracy: 60.00%, val Accuracy: 68.57%
# Epoch [65/100], Train Loss: 0.7668, Train Accuracy: 70.29%, Test Accuracy: 65.71%, val Accuracy: 51.43%
# Epoch [66/100], Train Loss: 0.7631, Train Accuracy: 69.20%, Test Accuracy: 65.71%, val Accuracy: 62.86%
# Epoch [67/100], Train Loss: 0.8106, Train Accuracy: 65.22%, Test Accuracy: 62.86%, val Accuracy: 60.00%
# Epoch [68/100], Train Loss: 0.7312, Train Accuracy: 71.74%, Test Accuracy: 62.86%, val Accuracy: 57.14%
# Epoch [69/100], Train Loss: 0.7961, Train Accuracy: 67.39%, Test Accuracy: 62.86%, val Accuracy: 65.71%
# Epoch [70/100], Train Loss: 0.7616, Train Accuracy: 69.20%, Test Accuracy: 74.29%, val Accuracy: 68.57%
# Epoch [71/100], Train Loss: 0.7821, Train Accuracy: 67.39%, Test Accuracy: 62.86%, val Accuracy: 60.00%
# Epoch [72/100], Train Loss: 0.6880, Train Accuracy: 72.46%, Test Accuracy: 62.86%, val Accuracy: 74.29%
# Epoch [73/100], Train Loss: 0.7450, Train Accuracy: 71.74%, Test Accuracy: 62.86%, val Accuracy: 71.43%
# Epoch [74/100], Train Loss: 0.7221, Train Accuracy: 69.20%, Test Accuracy: 80.00%, val Accuracy: 71.43%
# Epoch [75/100], Train Loss: 0.6687, Train Accuracy: 72.83%, Test Accuracy: 60.00%, val Accuracy: 57.14%
# Epoch [76/100], Train Loss: 0.7657, Train Accuracy: 69.93%, Test Accuracy: 57.14%, val Accuracy: 54.29%
# Epoch [77/100], Train Loss: 0.7519, Train Accuracy: 70.65%, Test Accuracy: 71.43%, val Accuracy: 62.86%
# Epoch [78/100], Train Loss: 0.7233, Train Accuracy: 72.46%, Test Accuracy: 54.29%, val Accuracy: 60.00%
# Epoch [79/100], Train Loss: 0.6731, Train Accuracy: 74.64%, Test Accuracy: 60.00%, val Accuracy: 60.00%
# Epoch [80/100], Train Loss: 0.6392, Train Accuracy: 75.72%, Test Accuracy: 54.29%, val Accuracy: 45.71%
# Epoch [81/100], Train Loss: 0.7325, Train Accuracy: 70.29%, Test Accuracy: 60.00%, val Accuracy: 62.86%
# Epoch [82/100], Train Loss: 0.6396, Train Accuracy: 71.74%, Test Accuracy: 60.00%, val Accuracy: 60.00%
# Epoch [83/100], Train Loss: 0.6985, Train Accuracy: 71.38%, Test Accuracy: 62.86%, val Accuracy: 60.00%
# Epoch [84/100], Train Loss: 0.6432, Train Accuracy: 72.46%, Test Accuracy: 62.86%, val Accuracy: 62.86%
# Epoch [85/100], Train Loss: 0.5713, Train Accuracy: 78.62%, Test Accuracy: 65.71%, val Accuracy: 60.00%
# Epoch [86/100], Train Loss: 0.6501, Train Accuracy: 75.72%, Test Accuracy: 62.86%, val Accuracy: 57.14%
# Epoch [87/100], Train Loss: 0.6750, Train Accuracy: 72.46%, Test Accuracy: 54.29%, val Accuracy: 57.14%
# Epoch [88/100], Train Loss: 0.6776, Train Accuracy: 73.91%, Test Accuracy: 80.00%, val Accuracy: 71.43%
# Epoch [89/100], Train Loss: 0.6058, Train Accuracy: 75.72%, Test Accuracy: 57.14%, val Accuracy: 60.00%
# Epoch [90/100], Train Loss: 0.6588, Train Accuracy: 72.10%, Test Accuracy: 57.14%, val Accuracy: 54.29%
# Epoch [91/100], Train Loss: 0.6437, Train Accuracy: 75.00%, Test Accuracy: 37.14%, val Accuracy: 20.00%
# Epoch [92/100], Train Loss: 0.6295, Train Accuracy: 71.74%, Test Accuracy: 60.00%, val Accuracy: 62.86%
# Epoch [93/100], Train Loss: 0.6050, Train Accuracy: 76.81%, Test Accuracy: 62.86%, val Accuracy: 62.86%
# Epoch [94/100], Train Loss: 0.5969, Train Accuracy: 73.19%, Test Accuracy: 60.00%, val Accuracy: 62.86%
# Epoch [95/100], Train Loss: 0.5718, Train Accuracy: 77.90%, Test Accuracy: 57.14%, val Accuracy: 62.86%
# Epoch [96/100], Train Loss: 0.5611, Train Accuracy: 76.81%, Test Accuracy: 57.14%, val Accuracy: 60.00%
# Epoch [97/100], Train Loss: 0.5817, Train Accuracy: 78.62%, Test Accuracy: 51.43%, val Accuracy: 51.43%
# Epoch [98/100], Train Loss: 0.5573, Train Accuracy: 78.62%, Test Accuracy: 68.57%, val Accuracy: 62.86%
# Epoch [99/100], Train Loss: 0.5248, Train Accuracy: 82.25%, Test Accuracy: 71.43%, val Accuracy: 71.43%
# Epoch [100/100], Train Loss: 0.5044, Train Accuracy: 80.80%, Test Accuracy: 71.43%, val Accuracy: 68.57%

# %%
print(total_correct)
print(val_correct)

print(test_acc)
# Out:
# 25
# 24
# 71.42857142857143

# %%
print(total_test_acc)
# Out:
# [34.285714285714285, 20.0, 48.57142857142857, 54.285714285714285, 42.857142857142854, 51.42857142857143, 22.857142857142858, 28.571428571428573, 40.0, 40.0, 45.714285714285715, 57.142857142857146, 42.857142857142854, 40.0, 51.42857142857143, 62.857142857142854, 65.71428571428571, 60.0, 65.71428571428571, 65.71428571428571, 68.57142857142857, 77.14285714285714, 60.0, 57.142857142857146, 31.428571428571427, 62.857142857142854, 42.857142857142854, 60.0, 54.285714285714285, 57.142857142857146, 45.714285714285715, 65.71428571428571, 28.571428571428573, 60.0, 54.285714285714285, 62.857142857142854, 60.0, 48.57142857142857, 57.142857142857146, 48.57142857142857, 60.0, 48.57142857142857, 51.42857142857143, 54.285714285714285, 62.857142857142854, 60.0, 62.857142857142854, 65.71428571428571, 57.142857142857146, 48.57142857142857, 68.57142857142857, 57.142857142857146, 65.71428571428571, 60.0, 42.857142857142854, 57.142857142857146, 51.42857142857143, 48.57142857142857, 65.71428571428571, 54.285714285714285, 48.57142857142857, 74.28571428571429, 48.57142857142857, 60.0, 65.71428571428571, 65.71428571428571, 62.857142857142854, 62.857142857142854, 62.857142857142854, 74.28571428571429, 62.857142857142854, 62.857142857142854, 62.857142857142854, 80.0, 60.0, 57.142857142857146, 71.42857142857143, 54.285714285714285, 60.0, 54.285714285714285, 60.0, 60.0, 62.857142857142854, 62.857142857142854, 65.71428571428571, 62.857142857142854, 54.285714285714285, 80.0, 57.142857142857146, 57.142857142857146, 37.142857142857146, 60.0, 62.857142857142854, 60.0, 57.142857142857146, 57.142857142857146, 51.42857142857143, 68.57142857142857, 71.42857142857143, 71.42857142857143]

# %%
sum_test_acc = 0
for i in range(len(total_test_acc)):
    sum_test_acc += total_test_acc[i]
    i += 1
    
sum_val_acc = 0
for i in range(len(total_val_acc)):
    sum_val_acc += total_val_acc[i]
    i += 1

# %%
print(sum_test_acc)
print(sum_test_acc/num_epochs)

print(sum_val_acc)
print(sum_val_acc/len(total_val_acc))

print(len(total_test_acc))
# Out:
# 5657.142857142856
# 56.57142857142856
# 5600.000000000003
# 56.00000000000003
# 100
